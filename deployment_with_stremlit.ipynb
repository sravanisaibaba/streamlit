# %%
# !pip install streamlit -q

# %%
! npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# changed 1 package in 4s
# ⠼

# %%
# %%writefile diabetesapp.py
import streamlit as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


#loading the dataset
df=pd.read_csv("/content/diabetes.csv")
df.isnull().sum()
df.describe()
df.info()
df.shape

#setting the target variable:
df["Outcome"].value_counts()

#grouping the data
df.groupby("Outcome").mean()
#0>>>non-diabitic patient
#1>>>>diabitic patient

#data visualization with no of pregnancy and outcomes
df.groupby("Outcome").mean().plot(kind="bar")
df.groupby("Outcome")["Pregnancies"].mean().plot(kind="bar")

#dividing the data in to x and y
x=df.drop("Outcome",axis=1)
x
y=df["Outcome"]
y
#train and testing the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=9,stratify=y)

#shape of the data sets that is traning and testing
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)

from sklearn import svm
classifier=svm.SVC(kernel="linear")#we have a target variable(0,1)so regression line can be taken
classifier.fit(x_train,y_train)

#model pridiction
prediction=classifier.predict(x_test)
prediction

from sklearn.metrics import accuracy_score
acc_score=accuracy_score(y_test,prediction)
acc_score

#creating  a data
array=np.array([5,175,72,19,166,25,57,62])
#reshaping array
reshaped_array=array.reshape(1,-1)


prediction_array=classifier.predict(reshaped_array)
if prediction_array[0]==0:
  print("Non Diabetic")
else:
  print("Diabetic")


st.title("Diabetics prediction for number of pregnencies")
#getting input from users:

pregnancies=st.text_input("number of pregnencies")
glucose=st.text_input("enter the glucose level")
Blood_pressure=st.text_input("enter the blood pressure")
skin_thickness=st.text_input("enter the skin thickness")
insulin=st.text_input("enter the insulin levels")
BMI=st.text_input("enter the BMI")
Diabatiespd=st.text_input("enter the dbp")
age=st.text_input("enter the age")

diagnosis=" "

if st.button("diabetes test results"):
  diagnosis=classifier.predict([[pregnancies,glucose,Blood_pressure,skin_thickness,insulin,BMI,Diabatiespd,age]])
  st.success(diagnosis)


  if diagnosis[0]==0:
    st.success("Non Diabetic")
  else:
    st.success("Diabetic")
# Out:
# Writing diabetesapp.py

# %%
# !streamlit run diabetesapp.py &>/content/logs.txt &

# %%
# !cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-02-24T14:27:24Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-02-24T14:27:24Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-02-24T14:27:28Z INF +--------------------------------------------------------------------------------------------+
# 2026-02-24T14:27:28Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...

# %%
df=pd.read_csv("/content/diabetes.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-220777661.py in <cell line: 0>()
# ----> 1 df=pd.read_csv("/content/diabetes.csv")
#
# NameError: name 'pd' is not defined

# %%
df.head()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df.info()

# %%
df.shape

# %%
#setting the target variable:
#grouping the outcome column
df["Outcome"].value_counts()

# %%
#grouping the data
df.groupby("Outcome").mean()
#0>>>non-diabitic patient
#1>>>>diabitic patient

# %%
#data visualization with no of pregnancy and outcomes
df.groupby("Outcome").mean().plot(kind="bar")

# %%
df.groupby("Outcome")["Pregnancies"].mean().plot(kind="bar")

# %%
df.pivot_table(index="Outcome",columns="Pregnancies",values="Age",aggfunc="mean").fillna(0)
#

# %%
#dividing the data in to x and y
x=df.drop("Outcome",axis=1)
x

# %%
y=df["Outcome"]
y

# %%
#train and testing the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=9,stratify=y)

# %%
#shape of the data sets that is traning and testing
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)

# %%
from sklearn import svm
classifier=svm.SVC(kernel="linear")#we have a target variable(0,1)so regression line can be taken
classifier.fit(x_train,y_train)

# %%
#pridiction
prediction=classifier.predict(x_test)
prediction

# %%
from sklearn.metrics import accuracy_score
acc_score=accuracy_score(y_test,prediction)
acc_score

# %%
#creating  a data
array=np.array([5,17,19,32,87,54,67,25.6])
#reshaping array
reshaped_array=array.reshape(1,-1)

# %%
prediction_array=classifier.predict(reshaped_array)
prediction_array
